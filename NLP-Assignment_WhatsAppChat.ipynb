# %%
import pandas as pd

# %%
df = pd.read_csv("mabel.txt",header=None,on_bad_lines='skip',encoding='utf8')

# %%
df
# Out:
#            0                                                  1
# 0   05/12/19   1:42 pm - Messages to this chat and calls are...
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...
# 12  05/12/19   1:44 pm - AR❤: Yeah Mam within Evening I will...
# 13  05/12/19   1:45 pm - AR❤: Tomorrow I have to visit the o...
# 14  05/12/19                      1:48 pm - Mabel Infoziant: ok
# 15  05/12/19   1:48 pm - Mabel Infoziant: send the details o...
# 16  05/12/19   1:49 pm - AR❤: Sure mam. Soon I will share de...
# 17  05/12/19   2:00 pm - AR❤: I have read the Abstract mam. ...
# 18  05/12/19   2:04 pm - Mabel Infoziant: I think Vignesh ha...
# 19  05/12/19   2:04 pm - Mabel Infoziant: I have sent the ab...
# 20  05/12/19                              2:06 pm - AR❤: Ok mam
# 21  05/12/19   2:07 pm - AR❤: I have read both the abstract ...
# 22  05/12/19   4:44 pm - Mabel Infoziant: Yes we need to ya ...
# 23  05/12/19                           4:48 pm - AR❤: Sure mam.
# 24  05/12/19                   8:07 pm - AR❤: Shall I call mam?
# 25  08/12/19   10:45 pm - Mabel Infoziant: Hi I was at churc...
# 26  08/12/19                         11:52 pm - AR❤: It's k mam
# 27  08/12/19   11:55 pm - AR❤: Just to know the tomorrow pla...
# 28  09/12/19    12:09 pm - AR❤: Mam can u send Vignesh number??
# 29  09/12/19   12:13 pm - Mabel Infoziant: Vignesh ML Infozi...
# 30  09/12/19   12:23 pm - Mabel Infoziant: I was in a meetin...
# 31  09/12/19                    12:25 pm - AR❤: Can I cal u mam
# 32  09/12/19   12:26 pm - AR❤: Waiting for u r finalization ...
# 33  09/12/19   12:26 pm - AR❤: If we finiliaze I can work wi...
# 34  09/12/19   12:28 pm - AR❤: So what ever may be ..if you ...
# 35  09/12/19           12:28 pm - AR❤: You deleted this message
# 36  09/12/19                     12:29 pm - AR❤: Do the needful
# 37  09/12/19   12:41 pm - Mabel Infoziant: No ma please hold...
# 38  09/12/19                     12:42 pm - AR❤: Ok mam thank u
# 39  10/12/19   7:59 am - Mabel Infoziant: Ramisha we need to...
# 40  10/12/19   8:00 am - Mabel Infoziant: Be ready to discus...
# 41  10/12/19                            8:55 am - AR❤: Okay mam
# 42  12/12/19                      2:26 pm - Mabel Infoziant: ok
# 43  15/12/19                     8:22 pm - AR❤: Mam are u free?
# 44  15/12/19   8:40 pm - Mabel Infoziant: Am at church can c...
# 45  15/12/19   8:40 pm - AR❤: Kk mam. I will ask Arun brothe...
# 46  18/12/19                              3:09 pm - AR❤: Hi mam
# 47  18/12/19                    3:09 pm - AR❤: Any updates mam?
# 48  18/12/19   3:11 pm - Mabel Infoziant: U might have to st...
# 49  18/12/19   3:11 pm - Mabel Infoziant: There is one proje...
# 50  18/12/19                            3:12 pm - AR❤: Kk mam👍🏻

# %%
df=df.drop(0)
df.columns=['Date','Chat']
Message=df["Chat"].str.split("-",n=1,expand=True)
df["Time"]=Message[0]
Message1=Message[1].str.split(":",n=1,expand=True)
df["Name"]=Message1[0]
df["Chat"]=Message1[1]
df=df[["Date","Time","Name","Chat"]]
df
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# 22  05/12/19    4:44 pm    Mabel Infoziant
# 23  05/12/19    4:48 pm                AR❤
# 24  05/12/19    8:07 pm                AR❤
# 25  08/12/19   10:45 pm    Mabel Infoziant
# 26  08/12/19   11:52 pm                AR❤
# 27  08/12/19   11:55 pm                AR❤
# 28  09/12/19   12:09 pm                AR❤
# 29  09/12/19   12:13 pm    Mabel Infoziant
# 30  09/12/19   12:23 pm    Mabel Infoziant
# 31  09/12/19   12:25 pm                AR❤
# 32  09/12/19   12:26 pm                AR❤
# 33  09/12/19   12:26 pm                AR❤
# 34  09/12/19   12:28 pm                AR❤
# 35  09/12/19   12:28 pm                AR❤
# 36  09/12/19   12:29 pm                AR❤
# 37  09/12/19   12:41 pm    Mabel Infoziant
# 38  09/12/19   12:42 pm                AR❤
# 39  10/12/19    7:59 am    Mabel Infoziant
# 40  10/12/19    8:00 am    Mabel Infoziant
# 41  10/12/19    8:55 am                AR❤
# 42  12/12/19    2:26 pm    Mabel Infoziant
# 43  15/12/19    8:22 pm                AR❤
# 44  15/12/19    8:40 pm    Mabel Infoziant
# 45  15/12/19    8:40 pm                AR❤
# 46  18/12/19    3:09 pm                AR❤
# 47  18/12/19    3:09 pm                AR❤
# 48  18/12/19    3:11 pm    Mabel Infoziant
# 49  18/12/19    3:11 pm    Mabel Infoziant
# 50  18/12/19    3:12 pm                AR❤
#
#                                                  Chat
# 1                      Hi this is Mabel we just spoke
# 2                               What’s your full name
# 3                                      Ramisha Rani K
# 4                                                  Ok
# 5                              ramisharanik@gmail.com
# 6                                      Your email Id?
# 7                                             Yes Mam
# 8      I will send 2 abstracts for u to start working
# 9                                            Yeah mam
# 10                   Give me the list that u have too
# 11   Send me cbe office address and phone number I...
# 12    Yeah Mam within Evening I will forward you mam.
# 13   Tomorrow I have to visit the office.yet not I...
# 14                                                 ok
# 15   send the details of office location once u ge...
# 16   Sure mam. Soon I will share details with you mam
# 17   I have read the Abstract mam. We can do mam. ...
# 18   I think Vignesh has the data set will ask him...
# 19                          I have sent the abstracts
# 20                                             Ok mam
# 21   I have read both the abstract mam. We can do ...
# 22   Yes we need to ya about amount and all other ...
# 23                                          Sure mam.
# 24                                  Shall I call mam?
# 25         Hi I was at church couldn’t take your call
# 26                                         It's k mam
# 27   Just to know the tomorrow plan mam.will see t...
# 28                    Mam can u send Vignesh number??
# 29           Vignesh ML Infoziant.vcf (file attached)
# 30                           I was in a meeting sorry
# 31                                    Can I cal u mam
# 32   Waiting for u r finalization of rates for our...
# 33   If we finiliaze I can work with full involvem...
# 34   So what ever may be ..if you think your are c...
# 35                           You deleted this message
# 36                                     Do the needful
# 37   No ma please hold I am in a hot meeting with ...
# 38                                     Ok mam thank u
# 39   Ramisha we need to talk today i will call u a...
# 40     Be ready to discuss about the ML titles u have
# 41                                           Okay mam
# 42                                                 ok
# 43                                    Mam are u free?
# 44   Am at church can call very late or tomorrow only
# 45   Kk mam. I will ask Arun brother. Small doubt ...
# 46                                             Hi mam
# 47                                   Any updates mam?
# 48     U might have to start on the WhatsApp analysis
# 49            There is one project that got committed
# 50                                           Kk mam👍🏻

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 1 to 50
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    50 non-null     object
#  1   Time    50 non-null     object
#  2   Name    50 non-null     object
#  3   Chat    50 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %% [markdown]
# ### Sentiment Analysis

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dataset=df

# %%
dataset.dropna(inplace=True)

# %%
sid = SentimentIntensityAnalyzer()

# %%
senti=sid.polarity_scores(dataset['Chat'][4])

# %%
senti
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}

# %%
 def sentimentalAnalysis(data,columnname):
        
        #downloading vader_lexicon for the process
        import matplotlib.pyplot as plt
        import seaborn as sns
        "Importing Necessary Packeage"
        from nltk.sentiment.vader import SentimentIntensityAnalyzer
        sid = SentimentIntensityAnalyzer()
        
        "Deleting null pr empty value"
        data.dropna(inplace=True)
        
        "Checking for a comment"
        #sid.polarity_scores(data[columnname][93])
        
        "Creating respective columns"
        
        data['scores'] = data[columnname].apply(lambda commentText: sid.polarity_scores(commentText))
        data['compound']  = data['scores'].apply(lambda score_dict: score_dict['compound'])
        data['Negtive']  = data['scores'].apply(lambda score_dict: score_dict['neg'])
        data['Postive']  = data['scores'].apply(lambda score_dict: score_dict['pos'])
        data['Neutral']  = data['scores'].apply(lambda score_dict: score_dict['neu'])
        
        "Creating final pos or neg using compound score"
        data['comp_score'] = data['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
        plt.clf()
        #comp=sns.countplot(x = 'comp_score', hue = 'Name', data = data, palette = 'magma')
        #comp.figure.savefig("date_charts.png")
        "Checking how many pos and neg"
        posneg=pd.DataFrame(data['comp_score'].value_counts())
        return posneg,data

# %%
pos,data_Senti=sentimentalAnalysis(dataset,columnname='Chat')

# %%
data_Senti
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# 22  05/12/19    4:44 pm    Mabel Infoziant
# 23  05/12/19    4:48 pm                AR❤
# 24  05/12/19    8:07 pm                AR❤
# 25  08/12/19   10:45 pm    Mabel Infoziant
# 26  08/12/19   11:52 pm                AR❤
# 27  08/12/19   11:55 pm                AR❤
# 28  09/12/19   12:09 pm                AR❤
# 29  09/12/19   12:13 pm    Mabel Infoziant
# 30  09/12/19   12:23 pm    Mabel Infoziant
# 31  09/12/19   12:25 pm                AR❤
# 32  09/12/19   12:26 pm                AR❤
# 33  09/12/19   12:26 pm                AR❤
# 34  09/12/19   12:28 pm                AR❤
# 35  09/12/19   12:28 pm                AR❤
# 36  09/12/19   12:29 pm                AR❤
# 37  09/12/19   12:41 pm    Mabel Infoziant
# 38  09/12/19   12:42 pm                AR❤
# 39  10/12/19    7:59 am    Mabel Infoziant
# 40  10/12/19    8:00 am    Mabel Infoziant
# 41  10/12/19    8:55 am                AR❤
# 42  12/12/19    2:26 pm    Mabel Infoziant
# 43  15/12/19    8:22 pm                AR❤
# 44  15/12/19    8:40 pm    Mabel Infoziant
# 45  15/12/19    8:40 pm                AR❤
# 46  18/12/19    3:09 pm                AR❤
# 47  18/12/19    3:09 pm                AR❤
# 48  18/12/19    3:11 pm    Mabel Infoziant
# 49  18/12/19    3:11 pm    Mabel Infoziant
# 50  18/12/19    3:12 pm                AR❤
#
#                                                  Chat  \
# 1                      Hi this is Mabel we just spoke
# 2                               What’s your full name
# 3                                      Ramisha Rani K
# 4                                                  Ok
# 5                              ramisharanik@gmail.com
# 6                                      Your email Id?
# 7                                             Yes Mam
# 8      I will send 2 abstracts for u to start working
# 9                                            Yeah mam
# 10                   Give me the list that u have too
# 11   Send me cbe office address and phone number I...
# 12    Yeah Mam within Evening I will forward you mam.
# 13   Tomorrow I have to visit the office.yet not I...
# 14                                                 ok
# 15   send the details of office location once u ge...
# 16   Sure mam. Soon I will share details with you mam
# 17   I have read the Abstract mam. We can do mam. ...
# 18   I think Vignesh has the data set will ask him...
# 19                          I have sent the abstracts
# 20                                             Ok mam
# 21   I have read both the abstract mam. We can do ...
# 22   Yes we need to ya about amount and all other ...
# 23                                          Sure mam.
# 24                                  Shall I call mam?
# 25         Hi I was at church couldn’t take your call
# 26                                         It's k mam
# 27   Just to know the tomorrow plan mam.will see t...
# 28                    Mam can u send Vignesh number??
# 29           Vignesh ML Infoziant.vcf (file attached)
# 30                           I was in a meeting sorry
# 31                                    Can I cal u mam
# 32   Waiting for u r finalization of rates for our...
# 33   If we finiliaze I can work with full involvem...
# 34   So what ever may be ..if you think your are c...
# 35                           You deleted this message
# 36                                     Do the needful
# 37   No ma please hold I am in a hot meeting with ...
# 38                                     Ok mam thank u
# 39   Ramisha we need to talk today i will call u a...
# 40     Be ready to discuss about the ML titles u have
# 41                                           Okay mam
# 42                                                 ok
# 43                                    Mam are u free?
# 44   Am at church can call very late or tomorrow only
# 45   Kk mam. I will ask Arun brother. Small doubt ...
# 46                                             Hi mam
# 47                                   Any updates mam?
# 48     U might have to start on the WhatsApp analysis
# 49            There is one project that got committed
# 50                                           Kk mam👍🏻
#
#                                                scores  compound  Negtive  \
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 4   {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 7   {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compou...    0.4019    0.000
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 9   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 11  {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'comp...    0.0772    0.000
# 12  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'comp...    0.2960    0.000
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 14  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 15  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'comp...    0.3612    0.000
# 16  {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'comp...    0.5423    0.000
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 20  {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 22  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...    0.4019    0.000
# 23  {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'comp...    0.3182    0.000
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 27  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4404    0.000
# 28  {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'comp...    0.1680    0.000
# 29  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 30  {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'comp...   -0.0772    0.302
# 31  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 32  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 33  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 34  {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'comp...    0.5106    0.000
# 35  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 36  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 37  {'neg': 0.174, 'neu': 0.736, 'pos': 0.089, 'co...   -0.2960    0.174
# 38  {'neg': 0.0, 'neu': 0.175, 'pos': 0.825, 'comp...    0.5719    0.000
# 39  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 40  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'comp...    0.3612    0.000
# 41  {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'comp...    0.2263    0.000
# 42  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 43  {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'comp...    0.5106    0.000
# 44  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 45  {'neg': 0.111, 'neu': 0.619, 'pos': 0.27, 'com...    0.5574    0.111
# 46  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 47  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 48  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 49  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...    0.2732    0.000
# 50  {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'comp...    0.3612    0.000
#
#     Postive  Neutral comp_score
# 1     0.000    1.000        pos
# 2     0.000    1.000        pos
# 3     0.000    1.000        pos
# 4     1.000    0.000        pos
# 5     0.000    1.000        pos
# 6     0.000    1.000        pos
# 7     0.730    0.270        pos
# 8     0.000    1.000        pos
# 9     0.688    0.312        pos
# 10    0.000    1.000        pos
# 11    0.085    0.915        pos
# 12    0.239    0.761        pos
# 13    0.000    1.000        pos
# 14    1.000    0.000        pos
# 15    0.104    0.896        pos
# 16    0.391    0.609        pos
# 17    0.000    1.000        pos
# 18    0.000    1.000        pos
# 19    0.000    1.000        pos
# 20    0.688    0.312        pos
# 21    0.000    1.000        pos
# 22    0.162    0.838        pos
# 23    0.697    0.303        pos
# 24    0.000    1.000        pos
# 25    0.000    1.000        pos
# 26    0.000    1.000        pos
# 27    0.225    0.775        pos
# 28    0.293    0.707        pos
# 29    0.000    1.000        pos
# 30    0.000    0.698        neg
# 31    0.000    1.000        pos
# 32    0.000    1.000        pos
# 33    0.000    1.000        pos
# 34    0.125    0.875        pos
# 35    0.000    1.000        pos
# 36    0.000    1.000        pos
# 37    0.089    0.736        neg
# 38    0.825    0.175        pos
# 39    0.000    1.000        pos
# 40    0.238    0.762        pos
# 41    0.655    0.345        pos
# 42    1.000    0.000        pos
# 43    0.623    0.377        pos
# 44    0.000    1.000        pos
# 45    0.270    0.619        pos
# 46    0.000    1.000        pos
# 47    0.000    1.000        pos
# 48    0.000    1.000        pos
# 49    0.259    0.741        pos
# 50    0.714    0.286        pos

# %%
import matplotlib.pyplot as plt

# Count sentiment per person
sentiment_counts = df.groupby(['Name', 'comp_score']).size().unstack(fill_value=0)

# Plot
sentiment_counts.plot(
    kind='bar',
    figsize=(8,5),
    color={'pos': 'purple', 'neg': 'blue'},
)

plt.title('Sentiment Analysis')
plt.ylabel('Message Count')
plt.xlabel('comp_score')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Topic Modelling - NMF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(max_df=0.95,min_df=2,stop_words='english')
dtm=tfidf.fit_transform(df["Chat"])

# %%
from sklearn.decomposition import NMF
nmf_model=NMF(n_components=5,random_state=42)
nmf_model.fit(dtm)
# Out:
# NMF(n_components=5, random_state=42)

# %%
for index,topic in enumerate(nmf_model.components_):
    results=([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print(results)
# Out:
# ['share', 'soon', 'ask', 'yes', 'sure', 'read', 'abstract', 'kk', 'yeah', 'mam']
# ['hi', 'kk', 'know', 'meeting', 'yes', 'just', 'send', 'tomorrow', 'mam', 'ok']
# ['details', 'abstracts', 'start', 'students', 'phone', 'ask', 'office', 'number', 'vignesh', 'send']
# ['ask', 'abstracts', 'number', 'mam', 'office', 'know', 'just', 'tomorrow', 'church', 'hi']
# ['students', 'know', 'sure', 'share', 'soon', 'meeting', 'details', 'yes', 'need', 'ramisha']

# %%
topic_results=nmf_model.transform(dtm)
df["Topic"]=topic_results.argmax(axis=1)

# %%
df
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# 22  05/12/19    4:44 pm    Mabel Infoziant
# 23  05/12/19    4:48 pm                AR❤
# 24  05/12/19    8:07 pm                AR❤
# 25  08/12/19   10:45 pm    Mabel Infoziant
# 26  08/12/19   11:52 pm                AR❤
# 27  08/12/19   11:55 pm                AR❤
# 28  09/12/19   12:09 pm                AR❤
# 29  09/12/19   12:13 pm    Mabel Infoziant
# 30  09/12/19   12:23 pm    Mabel Infoziant
# 31  09/12/19   12:25 pm                AR❤
# 32  09/12/19   12:26 pm                AR❤
# 33  09/12/19   12:26 pm                AR❤
# 34  09/12/19   12:28 pm                AR❤
# 35  09/12/19   12:28 pm                AR❤
# 36  09/12/19   12:29 pm                AR❤
# 37  09/12/19   12:41 pm    Mabel Infoziant
# 38  09/12/19   12:42 pm                AR❤
# 39  10/12/19    7:59 am    Mabel Infoziant
# 40  10/12/19    8:00 am    Mabel Infoziant
# 41  10/12/19    8:55 am                AR❤
# 42  12/12/19    2:26 pm    Mabel Infoziant
# 43  15/12/19    8:22 pm                AR❤
# 44  15/12/19    8:40 pm    Mabel Infoziant
# 45  15/12/19    8:40 pm                AR❤
# 46  18/12/19    3:09 pm                AR❤
# 47  18/12/19    3:09 pm                AR❤
# 48  18/12/19    3:11 pm    Mabel Infoziant
# 49  18/12/19    3:11 pm    Mabel Infoziant
# 50  18/12/19    3:12 pm                AR❤
#
#                                                  Chat  \
# 1                      Hi this is Mabel we just spoke
# 2                               What’s your full name
# 3                                      Ramisha Rani K
# 4                                                  Ok
# 5                              ramisharanik@gmail.com
# 6                                      Your email Id?
# 7                                             Yes Mam
# 8      I will send 2 abstracts for u to start working
# 9                                            Yeah mam
# 10                   Give me the list that u have too
# 11   Send me cbe office address and phone number I...
# 12    Yeah Mam within Evening I will forward you mam.
# 13   Tomorrow I have to visit the office.yet not I...
# 14                                                 ok
# 15   send the details of office location once u ge...
# 16   Sure mam. Soon I will share details with you mam
# 17   I have read the Abstract mam. We can do mam. ...
# 18   I think Vignesh has the data set will ask him...
# 19                          I have sent the abstracts
# 20                                             Ok mam
# 21   I have read both the abstract mam. We can do ...
# 22   Yes we need to ya about amount and all other ...
# 23                                          Sure mam.
# 24                                  Shall I call mam?
# 25         Hi I was at church couldn’t take your call
# 26                                         It's k mam
# 27   Just to know the tomorrow plan mam.will see t...
# 28                    Mam can u send Vignesh number??
# 29           Vignesh ML Infoziant.vcf (file attached)
# 30                           I was in a meeting sorry
# 31                                    Can I cal u mam
# 32   Waiting for u r finalization of rates for our...
# 33   If we finiliaze I can work with full involvem...
# 34   So what ever may be ..if you think your are c...
# 35                           You deleted this message
# 36                                     Do the needful
# 37   No ma please hold I am in a hot meeting with ...
# 38                                     Ok mam thank u
# 39   Ramisha we need to talk today i will call u a...
# 40     Be ready to discuss about the ML titles u have
# 41                                           Okay mam
# 42                                                 ok
# 43                                    Mam are u free?
# 44   Am at church can call very late or tomorrow only
# 45   Kk mam. I will ask Arun brother. Small doubt ...
# 46                                             Hi mam
# 47                                   Any updates mam?
# 48     U might have to start on the WhatsApp analysis
# 49            There is one project that got committed
# 50                                           Kk mam👍🏻
#
#                                                scores  compound  Negtive  \
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 4   {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 7   {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compou...    0.4019    0.000
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 9   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 11  {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'comp...    0.0772    0.000
# 12  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'comp...    0.2960    0.000
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 14  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 15  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'comp...    0.3612    0.000
# 16  {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'comp...    0.5423    0.000
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 20  {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 22  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...    0.4019    0.000
# 23  {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'comp...    0.3182    0.000
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 27  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4404    0.000
# 28  {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'comp...    0.1680    0.000
# 29  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 30  {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'comp...   -0.0772    0.302
# 31  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 32  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 33  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 34  {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'comp...    0.5106    0.000
# 35  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 36  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 37  {'neg': 0.174, 'neu': 0.736, 'pos': 0.089, 'co...   -0.2960    0.174
# 38  {'neg': 0.0, 'neu': 0.175, 'pos': 0.825, 'comp...    0.5719    0.000
# 39  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 40  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'comp...    0.3612    0.000
# 41  {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'comp...    0.2263    0.000
# 42  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 43  {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'comp...    0.5106    0.000
# 44  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 45  {'neg': 0.111, 'neu': 0.619, 'pos': 0.27, 'com...    0.5574    0.111
# 46  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 47  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 48  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 49  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...    0.2732    0.000
# 50  {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'comp...    0.3612    0.000
#
#     Postive  Neutral comp_score  Topic
# 1     0.000    1.000        pos      3
# 2     0.000    1.000        pos      0
# 3     0.000    1.000        pos      4
# 4     1.000    0.000        pos      1
# 5     0.000    1.000        pos      0
# 6     0.000    1.000        pos      0
# 7     0.730    0.270        pos      4
# 8     0.000    1.000        pos      2
# 9     0.688    0.312        pos      0
# 10    0.000    1.000        pos      0
# 11    0.085    0.915        pos      2
# 12    0.239    0.761        pos      0
# 13    0.000    1.000        pos      2
# 14    1.000    0.000        pos      1
# 15    0.104    0.896        pos      2
# 16    0.391    0.609        pos      0
# 17    0.000    1.000        pos      0
# 18    0.000    1.000        pos      2
# 19    0.000    1.000        pos      2
# 20    0.688    0.312        pos      1
# 21    0.000    1.000        pos      0
# 22    0.162    0.838        pos      4
# 23    0.697    0.303        pos      0
# 24    0.000    1.000        pos      0
# 25    0.000    1.000        pos      3
# 26    0.000    1.000        pos      0
# 27    0.225    0.775        pos      3
# 28    0.293    0.707        pos      2
# 29    0.000    1.000        pos      2
# 30    0.000    0.698        neg      4
# 31    0.000    1.000        pos      0
# 32    0.000    1.000        pos      0
# 33    0.000    1.000        pos      2
# 34    0.125    0.875        pos      0
# 35    0.000    1.000        pos      0
# 36    0.000    1.000        pos      0
# 37    0.089    0.736        neg      4
# 38    0.825    0.175        pos      1
# 39    0.000    1.000        pos      4
# 40    0.238    0.762        pos      2
# 41    0.655    0.345        pos      0
# 42    1.000    0.000        pos      1
# 43    0.623    0.377        pos      0
# 44    0.000    1.000        pos      3
# 45    0.270    0.619        pos      0
# 46    0.000    1.000        pos      3
# 47    0.000    1.000        pos      0
# 48    0.000    1.000        pos      2
# 49    0.259    0.741        pos      2
# 50    0.714    0.286        pos      0

# %%
df["Topic"].value_counts()
# Out:
# Topic
# 0    22
# 2    12
# 4     6
# 3     5
# 1     5
# Name: count, dtype: int64

# %% [markdown]
# ### Topic Modelling - LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation

# Create LDA model
lda_model = LatentDirichletAllocation(
    n_components=5,       # number of topics
    random_state=42,      # for reproducibility
    learning_method='batch'  # or 'online'
)

# Fit LDA model to your document-term matrix
lda_model.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
# Get feature names from your vectorizer
feature_names = tfidf.get_feature_names_out()  # or count_vectorizer.get_feature_names_out()

for topic_idx, topic in enumerate(lda_model.components_):
    top_features_idx = topic.argsort()[-10:][::-1]  # Top 10 words for each topic
    top_features = [feature_names[i] for i in top_features_idx]
    print(f"Topic {topic_idx+1}: {', '.join(top_features)}")
# Out:
# Topic 1: ml, vignesh, details, send, office, just, hi, yes, need, number
# Topic 2: ok, need, yes, students, phone, office, number, ramisha, soon, meeting
# Topic 3: mam, yeah, finiliaze, kk, sure, abstract, read, think, project, ask
# Topic 4: tomorrow, project, meeting, church, know, just, office, mam, ask, soon
# Topic 5: abstracts, start, hi, ramisha, church, send, mam, ask, yes, details

# %%
# Transform the document-term matrix into topic probabilities
doc_topic_dist = lda_model.transform(dtm)  # shape: (n_documents, n_topics)

# Average topic probabilities across all documents
topic_percentages = doc_topic_dist.mean(axis=0) * 100

# Print topic percentages
for i, perc in enumerate(topic_percentages, start=1):
    print(f"Topic {i}: {perc:.2f}%")
# Out:
# Topic 1: 18.01%
# Topic 2: 20.62%
# Topic 3: 30.16%
# Topic 4: 14.86%
# Topic 5: 16.35%

# %% [markdown]
# ### Word Cloud

# %%
#!pip install wordCloud

# %%
dataset=df
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
import matplotlib.pyplot as plt
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
comment_words = []
stoplist = stopwords.words('english')
stoplist.extend(['omitted', 'voice','missed','call','video','deleted','media','message'])
dataset.index=range(dataset.shape[0])
for i in range(1,len(dataset)): 
    comment_words.append(dataset['Chat'][i])
    vv=" ".join(comment_words)          
    wordcloud = WordCloud(width = 800, height = 800, 
                                background_color ='white', 
                                      stopwords = stoplist, 
                                      min_font_size = 10).generate(vv)      
plt.figure(figsize = (9, 7), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.savefig('wordcloud.PNG')
plt.show() 
print("Successfully created")
# Out:
# Successfully created

# %%
vv
# Out:
# " What’s your full name  Ramisha Rani K  Ok  ramisharanik@gmail.com  Your email Id?  Yes Mam  I will send 2 abstracts for u to start working  Yeah mam  Give me the list that u have too  Send me cbe office address and phone number I will ask students to come and meet u  Yeah Mam within Evening I will forward you mam.  Tomorrow I have to visit the office.yet not I haven't visited. Office name is Infotest Lab R.S Purum  ok  send the details of office location once u get it....also the phone number we need to give to students? let me know..so that i can share those to the marketing calls we have here  Sure mam. Soon I will share details with you mam  I have read the Abstract mam. We can do mam. Now I searching for dataset for the same. Once I get it. Will inform you mam.  I think Vignesh has the data set will ask him to send the details  I have sent the abstracts  Ok mam  I have read both the abstract mam. We can do both mam.  Yes we need to ya about amount and all other details can I call u after 7pm  Sure mam.  Shall I call mam?  Hi I was at church couldn’t take your call  It's k mam  Just to know the tomorrow plan mam.will see tomorrow. Good night.  Mam can u send Vignesh number??  Vignesh ML Infoziant.vcf (file attached)  I was in a meeting sorry  Can I cal u mam  Waiting for u r finalization of rates for our projects and other things...  If we finiliaze I can work with full involvement..  So what ever may be ..if you think your are comfortable with the price I asked for a project ..or any negotiation we can finiliaze mam.  You deleted this message  Do the needful  No ma please hold I am in a hot meeting with auditor and financial tension nothing to do with your discussion I will  call u soon  Ok mam thank u  Ramisha we need to talk today i will call u around 10:30  Be ready to discuss about the ML titles u have  Okay mam  ok  Mam are u free?  Am at church can call very late or tomorrow only  Kk mam. I will ask Arun brother. Small doubt . Not a issue mam. U carry on mam. Praise the lord.  Hi mam  Any updates mam?  U might have to start on the WhatsApp analysis  There is one project that got committed  Kk mam👍🏻"

# %%
df["Name"].value_counts()
# Out:
# Name
# AR❤                27
# Mabel Infoziant    23
# Name: count, dtype: int64

# %% [markdown]
# ### Date wise Message count

# %%
#df['Date'] = pd.to_datetime(df['Date'])

# Count messages per Name per Date
count_by_date = df.groupby(["Date", "Name"]).size().reset_index(name="Message_Count")

# Find the top speaker for each date
top_speakers = count_by_date.loc[count_by_date.groupby("Date")["Message_Count"].idxmax()]

print(top_speakers)
# Out:
#         Date              Name  Message_Count
# 1   05/12/19   Mabel Infoziant             13
# 2   08/12/19               AR❤              2
# 4   09/12/19               AR❤              8
# 7   10/12/19   Mabel Infoziant              2
# 8   12/12/19   Mabel Infoziant              1
# 9   15/12/19               AR❤              2
# 11  18/12/19               AR❤              3

# %%
# Pivot so each Name becomes a separate column
pivot_df = count_by_date.pivot(index="Date", columns="Name", values="Message_Count").fillna(0)

# Plot
pivot_df.plot(kind="bar", figsize=(10,6))

plt.title("Date-wise Message Count per User")
plt.xlabel("Date")
plt.ylabel("Message Count")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title="User")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Flirt Encounters

# %%
flirt_words = ["baby", "darling", "sweetheart","miss you", "cute", "handsome", "pretty", "love you", "dear", "honey"]

def is_flirty(text):
    text = str(text).lower()
    return any(word in text for word in flirt_words)

#  Mark Flirty Messages
df['IsFlirty'] = df['Chat'].apply(is_flirty)

#  Message Count per User
msg_count = df.groupby('Name')['Chat'].count().reset_index(name='MessageCount')

# Most & Least Talkative
most_talkative = msg_count.sort_values(by='MessageCount', ascending=False).iloc[0]
least_talkative = msg_count.sort_values(by='MessageCount', ascending=True).iloc[0]

#  Flirt Percentage per User
flirt_stats = df.groupby('Name')['IsFlirty'].mean().reset_index(name='FlirtPercentage')
flirt_stats['FlirtPercentage'] = flirt_stats['FlirtPercentage'] * 100

final_stats = msg_count.merge(flirt_stats, on='Name')

print("Chat Summary per User")
print(final_stats)
# Out:
# Chat Summary per User
#                Name  MessageCount  FlirtPercentage
# 0               AR❤            27              0.0
# 1   Mabel Infoziant            23              0.0

# %%
print("Flirt Encounter")
print("***************")
print("\n Most Talkative:")
print(f"{most_talkative['Name']} with {most_talkative['MessageCount']} messages")

print("\n Least Talkative:")
print(f"{least_talkative['Name']} with {least_talkative['MessageCount']} messages")

print("\n Flirt Percentage per User:")
for _, row in final_stats.iterrows():
    print(f"{row['Name']}: {row['FlirtPercentage']:.1f}%")
# Out:
# Flirt Encounter
# ***************
#
#  Most Talkative:
#  AR❤ with 27 messages
#
#  Least Talkative:
#  Mabel Infoziant with 23 messages
#
#  Flirt Percentage per User:
#  AR❤: 0.0%
#  Mabel Infoziant: 0.0%

# %%
final_stats
# Out:
#                Name  MessageCount  FlirtPercentage
# 0               AR❤            27              0.0
# 1   Mabel Infoziant            23              0.0

# %%
df
# Out:
#         Date        Time              Name  \
# 0   05/12/19    1:42 pm    Mabel Infoziant
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm                AR❤
# 3   05/12/19    1:42 pm    Mabel Infoziant
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:43 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm                AR❤
# 7   05/12/19    1:43 pm    Mabel Infoziant
# 8   05/12/19    1:43 pm                AR❤
# 9   05/12/19    1:43 pm    Mabel Infoziant
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:44 pm                AR❤
# 12  05/12/19    1:45 pm                AR❤
# 13  05/12/19    1:48 pm    Mabel Infoziant
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:49 pm                AR❤
# 16  05/12/19    2:00 pm                AR❤
# 17  05/12/19    2:04 pm    Mabel Infoziant
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:06 pm                AR❤
# 20  05/12/19    2:07 pm                AR❤
# 21  05/12/19    4:44 pm    Mabel Infoziant
# 22  05/12/19    4:48 pm                AR❤
# 23  05/12/19    8:07 pm                AR❤
# 24  08/12/19   10:45 pm    Mabel Infoziant
# 25  08/12/19   11:52 pm                AR❤
# 26  08/12/19   11:55 pm                AR❤
# 27  09/12/19   12:09 pm                AR❤
# 28  09/12/19   12:13 pm    Mabel Infoziant
# 29  09/12/19   12:23 pm    Mabel Infoziant
# 30  09/12/19   12:25 pm                AR❤
# 31  09/12/19   12:26 pm                AR❤
# 32  09/12/19   12:26 pm                AR❤
# 33  09/12/19   12:28 pm                AR❤
# 34  09/12/19   12:28 pm                AR❤
# 35  09/12/19   12:29 pm                AR❤
# 36  09/12/19   12:41 pm    Mabel Infoziant
# 37  09/12/19   12:42 pm                AR❤
# 38  10/12/19    7:59 am    Mabel Infoziant
# 39  10/12/19    8:00 am    Mabel Infoziant
# 40  10/12/19    8:55 am                AR❤
# 41  12/12/19    2:26 pm    Mabel Infoziant
# 42  15/12/19    8:22 pm                AR❤
# 43  15/12/19    8:40 pm    Mabel Infoziant
# 44  15/12/19    8:40 pm                AR❤
# 45  18/12/19    3:09 pm                AR❤
# 46  18/12/19    3:09 pm                AR❤
# 47  18/12/19    3:11 pm    Mabel Infoziant
# 48  18/12/19    3:11 pm    Mabel Infoziant
# 49  18/12/19    3:12 pm                AR❤
#
#                                                  Chat  \
# 0                      Hi this is Mabel we just spoke
# 1                               What’s your full name
# 2                                      Ramisha Rani K
# 3                                                  Ok
# 4                              ramisharanik@gmail.com
# 5                                      Your email Id?
# 6                                             Yes Mam
# 7      I will send 2 abstracts for u to start working
# 8                                            Yeah mam
# 9                    Give me the list that u have too
# 10   Send me cbe office address and phone number I...
# 11    Yeah Mam within Evening I will forward you mam.
# 12   Tomorrow I have to visit the office.yet not I...
# 13                                                 ok
# 14   send the details of office location once u ge...
# 15   Sure mam. Soon I will share details with you mam
# 16   I have read the Abstract mam. We can do mam. ...
# 17   I think Vignesh has the data set will ask him...
# 18                          I have sent the abstracts
# 19                                             Ok mam
# 20   I have read both the abstract mam. We can do ...
# 21   Yes we need to ya about amount and all other ...
# 22                                          Sure mam.
# 23                                  Shall I call mam?
# 24         Hi I was at church couldn’t take your call
# 25                                         It's k mam
# 26   Just to know the tomorrow plan mam.will see t...
# 27                    Mam can u send Vignesh number??
# 28           Vignesh ML Infoziant.vcf (file attached)
# 29                           I was in a meeting sorry
# 30                                    Can I cal u mam
# 31   Waiting for u r finalization of rates for our...
# 32   If we finiliaze I can work with full involvem...
# 33   So what ever may be ..if you think your are c...
# 34                           You deleted this message
# 35                                     Do the needful
# 36   No ma please hold I am in a hot meeting with ...
# 37                                     Ok mam thank u
# 38   Ramisha we need to talk today i will call u a...
# 39     Be ready to discuss about the ML titles u have
# 40                                           Okay mam
# 41                                                 ok
# 42                                    Mam are u free?
# 43   Am at church can call very late or tomorrow only
# 44   Kk mam. I will ask Arun brother. Small doubt ...
# 45                                             Hi mam
# 46                                   Any updates mam?
# 47     U might have to start on the WhatsApp analysis
# 48            There is one project that got committed
# 49                                           Kk mam👍🏻
#
#                                                scores  compound  Negtive  \
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 3   {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 6   {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compou...    0.4019    0.000
# 7   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 8   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 10  {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'comp...    0.0772    0.000
# 11  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'comp...    0.2960    0.000
# 12  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 13  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 14  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'comp...    0.3612    0.000
# 15  {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'comp...    0.5423    0.000
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 19  {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 20  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 21  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...    0.4019    0.000
# 22  {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'comp...    0.3182    0.000
# 23  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 26  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4404    0.000
# 27  {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'comp...    0.1680    0.000
# 28  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 29  {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'comp...   -0.0772    0.302
# 30  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 31  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 32  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 33  {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'comp...    0.5106    0.000
# 34  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 35  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 36  {'neg': 0.174, 'neu': 0.736, 'pos': 0.089, 'co...   -0.2960    0.174
# 37  {'neg': 0.0, 'neu': 0.175, 'pos': 0.825, 'comp...    0.5719    0.000
# 38  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 39  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'comp...    0.3612    0.000
# 40  {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'comp...    0.2263    0.000
# 41  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 42  {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'comp...    0.5106    0.000
# 43  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 44  {'neg': 0.111, 'neu': 0.619, 'pos': 0.27, 'com...    0.5574    0.111
# 45  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 46  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 47  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 48  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...    0.2732    0.000
# 49  {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'comp...    0.3612    0.000
#
#     Postive  Neutral comp_score  Topic  IsFlirty
# 0     0.000    1.000        pos      3     False
# 1     0.000    1.000        pos      0     False
# 2     0.000    1.000        pos      4     False
# 3     1.000    0.000        pos      1     False
# 4     0.000    1.000        pos      0     False
# 5     0.000    1.000        pos      0     False
# 6     0.730    0.270        pos      4     False
# 7     0.000    1.000        pos      2     False
# 8     0.688    0.312        pos      0     False
# 9     0.000    1.000        pos      0     False
# 10    0.085    0.915        pos      2     False
# 11    0.239    0.761        pos      0     False
# 12    0.000    1.000        pos      2     False
# 13    1.000    0.000        pos      1     False
# 14    0.104    0.896        pos      2     False
# 15    0.391    0.609        pos      0     False
# 16    0.000    1.000        pos      0     False
# 17    0.000    1.000        pos      2     False
# 18    0.000    1.000        pos      2     False
# 19    0.688    0.312        pos      1     False
# 20    0.000    1.000        pos      0     False
# 21    0.162    0.838        pos      4     False
# 22    0.697    0.303        pos      0     False
# 23    0.000    1.000        pos      0     False
# 24    0.000    1.000        pos      3     False
# 25    0.000    1.000        pos      0     False
# 26    0.225    0.775        pos      3     False
# 27    0.293    0.707        pos      2     False
# 28    0.000    1.000        pos      2     False
# 29    0.000    0.698        neg      4     False
# 30    0.000    1.000        pos      0     False
# 31    0.000    1.000        pos      0     False
# 32    0.000    1.000        pos      2     False
# 33    0.125    0.875        pos      0     False
# 34    0.000    1.000        pos      0     False
# 35    0.000    1.000        pos      0     False
# 36    0.089    0.736        neg      4     False
# 37    0.825    0.175        pos      1     False
# 38    0.000    1.000        pos      4     False
# 39    0.238    0.762        pos      2     False
# 40    0.655    0.345        pos      0     False
# 41    1.000    0.000        pos      1     False
# 42    0.623    0.377        pos      0     False
# 43    0.000    1.000        pos      3     False
# 44    0.270    0.619        pos      0     False
# 45    0.000    1.000        pos      3     False
# 46    0.000    1.000        pos      0     False
# 47    0.000    1.000        pos      2     False
# 48    0.259    0.741        pos      2     False
# 49    0.714    0.286        pos      0     False

# %% [markdown]
# ### Time Encounters

# %%
# Ensure DateTime column is created from Date + Time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'])

# Extract components
df['OnlyDate'] = df['DateTime'].dt.date
df['DayName'] = df['DateTime'].dt.day_name()
df['OnlyTime'] = df['DateTime'].dt.strftime('%I:%M %p')  # 12-hour format

# Most active date
most_active_date = df['OnlyDate'].value_counts().idxmax()

# Most active day of week
most_active_day = df['DayName'].value_counts().idxmax()

# Most active hour (actually specific minute)
most_active_hour = df['OnlyTime'].value_counts().idxmax()

# Average messages per day
avg_msgs_per_day = df.groupby('OnlyDate').size().mean()

# Display
print("Time Encounters:")
print("*****************")
print(f"Most Active Date: {most_active_date.strftime('%d/%m/%y')}")
print(f"Most Active Day: {most_active_day}")
print(f"Most Active Hour: {most_active_hour}")
print(f"Average Number of Message per Day: {avg_msgs_per_day:.1f}")
# Out:
# Time Encounters:
# *****************
# Most Active Date: 12/05/19
# Most Active Day: Sunday
# Most Active Hour: 01:43 PM
# Average Number of Message per Day: 7.1
# C:\Users\admin\AppData\Local\Temp\ipykernel_27064\3863577644.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'])

# %%
most_active_hour
# Out:
# '01:43 PM'

# %%
most_active_date
# Out:
# datetime.date(2019, 5, 12)

# %%
df
# Out:
#         Date        Time              Name  \
# 0   05/12/19    1:42 pm    Mabel Infoziant
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm                AR❤
# 3   05/12/19    1:42 pm    Mabel Infoziant
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:43 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm                AR❤
# 7   05/12/19    1:43 pm    Mabel Infoziant
# 8   05/12/19    1:43 pm                AR❤
# 9   05/12/19    1:43 pm    Mabel Infoziant
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:44 pm                AR❤
# 12  05/12/19    1:45 pm                AR❤
# 13  05/12/19    1:48 pm    Mabel Infoziant
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:49 pm                AR❤
# 16  05/12/19    2:00 pm                AR❤
# 17  05/12/19    2:04 pm    Mabel Infoziant
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:06 pm                AR❤
# 20  05/12/19    2:07 pm                AR❤
# 21  05/12/19    4:44 pm    Mabel Infoziant
# 22  05/12/19    4:48 pm                AR❤
# 23  05/12/19    8:07 pm                AR❤
# 24  08/12/19   10:45 pm    Mabel Infoziant
# 25  08/12/19   11:52 pm                AR❤
# 26  08/12/19   11:55 pm                AR❤
# 27  09/12/19   12:09 pm                AR❤
# 28  09/12/19   12:13 pm    Mabel Infoziant
# 29  09/12/19   12:23 pm    Mabel Infoziant
# 30  09/12/19   12:25 pm                AR❤
# 31  09/12/19   12:26 pm                AR❤
# 32  09/12/19   12:26 pm                AR❤
# 33  09/12/19   12:28 pm                AR❤
# 34  09/12/19   12:28 pm                AR❤
# 35  09/12/19   12:29 pm                AR❤
# 36  09/12/19   12:41 pm    Mabel Infoziant
# 37  09/12/19   12:42 pm                AR❤
# 38  10/12/19    7:59 am    Mabel Infoziant
# 39  10/12/19    8:00 am    Mabel Infoziant
# 40  10/12/19    8:55 am                AR❤
# 41  12/12/19    2:26 pm    Mabel Infoziant
# 42  15/12/19    8:22 pm                AR❤
# 43  15/12/19    8:40 pm    Mabel Infoziant
# 44  15/12/19    8:40 pm                AR❤
# 45  18/12/19    3:09 pm                AR❤
# 46  18/12/19    3:09 pm                AR❤
# 47  18/12/19    3:11 pm    Mabel Infoziant
# 48  18/12/19    3:11 pm    Mabel Infoziant
# 49  18/12/19    3:12 pm                AR❤
#
#                                                  Chat  \
# 0                      Hi this is Mabel we just spoke
# 1                               What’s your full name
# 2                                      Ramisha Rani K
# 3                                                  Ok
# 4                              ramisharanik@gmail.com
# 5                                      Your email Id?
# 6                                             Yes Mam
# 7      I will send 2 abstracts for u to start working
# 8                                            Yeah mam
# 9                    Give me the list that u have too
# 10   Send me cbe office address and phone number I...
# 11    Yeah Mam within Evening I will forward you mam.
# 12   Tomorrow I have to visit the office.yet not I...
# 13                                                 ok
# 14   send the details of office location once u ge...
# 15   Sure mam. Soon I will share details with you mam
# 16   I have read the Abstract mam. We can do mam. ...
# 17   I think Vignesh has the data set will ask him...
# 18                          I have sent the abstracts
# 19                                             Ok mam
# 20   I have read both the abstract mam. We can do ...
# 21   Yes we need to ya about amount and all other ...
# 22                                          Sure mam.
# 23                                  Shall I call mam?
# 24         Hi I was at church couldn’t take your call
# 25                                         It's k mam
# 26   Just to know the tomorrow plan mam.will see t...
# 27                    Mam can u send Vignesh number??
# 28           Vignesh ML Infoziant.vcf (file attached)
# 29                           I was in a meeting sorry
# 30                                    Can I cal u mam
# 31   Waiting for u r finalization of rates for our...
# 32   If we finiliaze I can work with full involvem...
# 33   So what ever may be ..if you think your are c...
# 34                           You deleted this message
# 35                                     Do the needful
# 36   No ma please hold I am in a hot meeting with ...
# 37                                     Ok mam thank u
# 38   Ramisha we need to talk today i will call u a...
# 39     Be ready to discuss about the ML titles u have
# 40                                           Okay mam
# 41                                                 ok
# 42                                    Mam are u free?
# 43   Am at church can call very late or tomorrow only
# 44   Kk mam. I will ask Arun brother. Small doubt ...
# 45                                             Hi mam
# 46                                   Any updates mam?
# 47     U might have to start on the WhatsApp analysis
# 48            There is one project that got committed
# 49                                           Kk mam👍🏻
#
#                                                scores  compound  Negtive  \
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 3   {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 6   {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compou...    0.4019    0.000
# 7   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 8   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 10  {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'comp...    0.0772    0.000
# 11  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'comp...    0.2960    0.000
# 12  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 13  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 14  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'comp...    0.3612    0.000
# 15  {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'comp...    0.5423    0.000
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 19  {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 20  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 21  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...    0.4019    0.000
# 22  {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'comp...    0.3182    0.000
# 23  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 26  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4404    0.000
# 27  {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'comp...    0.1680    0.000
# 28  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 29  {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'comp...   -0.0772    0.302
# 30  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 31  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 32  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 33  {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'comp...    0.5106    0.000
# 34  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 35  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 36  {'neg': 0.174, 'neu': 0.736, 'pos': 0.089, 'co...   -0.2960    0.174
# 37  {'neg': 0.0, 'neu': 0.175, 'pos': 0.825, 'comp...    0.5719    0.000
# 38  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 39  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'comp...    0.3612    0.000
# 40  {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'comp...    0.2263    0.000
# 41  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 42  {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'comp...    0.5106    0.000
# 43  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 44  {'neg': 0.111, 'neu': 0.619, 'pos': 0.27, 'com...    0.5574    0.111
# 45  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 46  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 47  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 48  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...    0.2732    0.000
# 49  {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'comp...    0.3612    0.000
#
#     Postive  Neutral comp_score  Topic  IsFlirty            DateTime  \
# 0     0.000    1.000        pos      3     False 2019-05-12 13:42:00
# 1     0.000    1.000        pos      0     False 2019-05-12 13:42:00
# 2     0.000    1.000        pos      4     False 2019-05-12 13:42:00
# 3     1.000    0.000        pos      1     False 2019-05-12 13:42:00
# 4     0.000    1.000        pos      0     False 2019-05-12 13:42:00
# 5     0.000    1.000        pos      0     False 2019-05-12 13:43:00
# 6     0.730    0.270        pos      4     False 2019-05-12 13:43:00
# 7     0.000    1.000        pos      2     False 2019-05-12 13:43:00
# 8     0.688    0.312        pos      0     False 2019-05-12 13:43:00
# 9     0.000    1.000        pos      0     False 2019-05-12 13:43:00
# 10    0.085    0.915        pos      2     False 2019-05-12 13:43:00
# 11    0.239    0.761        pos      0     False 2019-05-12 13:44:00
# 12    0.000    1.000        pos      2     False 2019-05-12 13:45:00
# 13    1.000    0.000        pos      1     False 2019-05-12 13:48:00
# 14    0.104    0.896        pos      2     False 2019-05-12 13:48:00
# 15    0.391    0.609        pos      0     False 2019-05-12 13:49:00
# 16    0.000    1.000        pos      0     False 2019-05-12 14:00:00
# 17    0.000    1.000        pos      2     False 2019-05-12 14:04:00
# 18    0.000    1.000        pos      2     False 2019-05-12 14:04:00
# 19    0.688    0.312        pos      1     False 2019-05-12 14:06:00
# 20    0.000    1.000        pos      0     False 2019-05-12 14:07:00
# 21    0.162    0.838        pos      4     False 2019-05-12 16:44:00
# 22    0.697    0.303        pos      0     False 2019-05-12 16:48:00
# 23    0.000    1.000        pos      0     False 2019-05-12 20:07:00
# 24    0.000    1.000        pos      3     False 2019-08-12 22:45:00
# 25    0.000    1.000        pos      0     False 2019-08-12 23:52:00
# 26    0.225    0.775        pos      3     False 2019-08-12 23:55:00
# 27    0.293    0.707        pos      2     False 2019-09-12 12:09:00
# 28    0.000    1.000        pos      2     False 2019-09-12 12:13:00
# 29    0.000    0.698        neg      4     False 2019-09-12 12:23:00
# 30    0.000    1.000        pos      0     False 2019-09-12 12:25:00
# 31    0.000    1.000        pos      0     False 2019-09-12 12:26:00
# 32    0.000    1.000        pos      2     False 2019-09-12 12:26:00
# 33    0.125    0.875        pos      0     False 2019-09-12 12:28:00
# 34    0.000    1.000        pos      0     False 2019-09-12 12:28:00
# 35    0.000    1.000        pos      0     False 2019-09-12 12:29:00
# 36    0.089    0.736        neg      4     False 2019-09-12 12:41:00
# 37    0.825    0.175        pos      1     False 2019-09-12 12:42:00
# 38    0.000    1.000        pos      4     False 2019-10-12 07:59:00
# 39    0.238    0.762        pos      2     False 2019-10-12 08:00:00
# 40    0.655    0.345        pos      0     False 2019-10-12 08:55:00
# 41    1.000    0.000        pos      1     False 2019-12-12 14:26:00
# 42    0.623    0.377        pos      0     False 2019-12-15 20:22:00
# 43    0.000    1.000        pos      3     False 2019-12-15 20:40:00
# 44    0.270    0.619        pos      0     False 2019-12-15 20:40:00
# 45    0.000    1.000        pos      3     False 2019-12-18 15:09:00
# 46    0.000    1.000        pos      0     False 2019-12-18 15:09:00
# 47    0.000    1.000        pos      2     False 2019-12-18 15:11:00
# 48    0.259    0.741        pos      2     False 2019-12-18 15:11:00
# 49    0.714    0.286        pos      0     False 2019-12-18 15:12:00
#
#       OnlyDate    DayName  OnlyTime
# 0   2019-05-12     Sunday  01:42 PM
# 1   2019-05-12     Sunday  01:42 PM
# 2   2019-05-12     Sunday  01:42 PM
# 3   2019-05-12     Sunday  01:42 PM
# 4   2019-05-12     Sunday  01:42 PM
# 5   2019-05-12     Sunday  01:43 PM
# 6   2019-05-12     Sunday  01:43 PM
# 7   2019-05-12     Sunday  01:43 PM
# 8   2019-05-12     Sunday  01:43 PM
# 9   2019-05-12     Sunday  01:43 PM
# 10  2019-05-12     Sunday  01:43 PM
# 11  2019-05-12     Sunday  01:44 PM
# 12  2019-05-12     Sunday  01:45 PM
# 13  2019-05-12     Sunday  01:48 PM
# 14  2019-05-12     Sunday  01:48 PM
# 15  2019-05-12     Sunday  01:49 PM
# 16  2019-05-12     Sunday  02:00 PM
# 17  2019-05-12     Sunday  02:04 PM
# 18  2019-05-12     Sunday  02:04 PM
# 19  2019-05-12     Sunday  02:06 PM
# 20  2019-05-12     Sunday  02:07 PM
# 21  2019-05-12     Sunday  04:44 PM
# 22  2019-05-12     Sunday  04:48 PM
# 23  2019-05-12     Sunday  08:07 PM
# 24  2019-08-12     Monday  10:45 PM
# 25  2019-08-12     Monday  11:52 PM
# 26  2019-08-12     Monday  11:55 PM
# 27  2019-09-12   Thursday  12:09 PM
# 28  2019-09-12   Thursday  12:13 PM
# 29  2019-09-12   Thursday  12:23 PM
# 30  2019-09-12   Thursday  12:25 PM
# 31  2019-09-12   Thursday  12:26 PM
# 32  2019-09-12   Thursday  12:26 PM
# 33  2019-09-12   Thursday  12:28 PM
# 34  2019-09-12   Thursday  12:28 PM
# 35  2019-09-12   Thursday  12:29 PM
# 36  2019-09-12   Thursday  12:41 PM
# 37  2019-09-12   Thursday  12:42 PM
# 38  2019-10-12   Saturday  07:59 AM
# 39  2019-10-12   Saturday  08:00 AM
# 40  2019-10-12   Saturday  08:55 AM
# 41  2019-12-12   Thursday  02:26 PM
# 42  2019-12-15     Sunday  08:22 PM
# 43  2019-12-15     Sunday  08:40 PM
# 44  2019-12-15     Sunday  08:40 PM
# 45  2019-12-18  Wednesday  03:09 PM
# 46  2019-12-18  Wednesday  03:09 PM
# 47  2019-12-18  Wednesday  03:11 PM
# 48  2019-12-18  Wednesday  03:11 PM
# 49  2019-12-18  Wednesday  03:12 PM

# %% [markdown]
# ### Media Encounters

# %%
df['Chat'] = df['Chat'].astype(str).str.lower()

# 1. Media count
media_count = df['Chat'].str.contains("media omitted").sum()

# 2. Deleted messages count
deleted_count = df['Chat'].str.contains("this message was deleted").sum()

# 3. Missed voice call count
missed_voice_count = df['Chat'].str.contains("missed voice call").sum()

# 4. Missed video call count
missed_video_count = df['Chat'].str.contains("missed video call").sum()

# Display
print("Media Encounters")
print("*****************")
print(f"Media Count:",media_count)
print(f"Deleted Message Count:{deleted_count}")
print(f"Missed Voice Call Count:",missed_voice_count)
print(f"Missed Video Call count:",missed_video_count)
# Out:
# Media Encounters
# *****************
# Media Count: 0
# Deleted Message Count:0
# Missed Voice Call Count: 0
# Missed Video Call count: 0
